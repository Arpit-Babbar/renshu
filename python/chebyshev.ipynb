# %% [markdown]
# # Plotting Chebyshev, Chebshev-Lobatoo and extended Chebyshev nodes

# %%
import numpy as np
from numpy import pi,cos
import matplotlib.pyplot as plt

# %%
m = 19
np.arange(0,m+1)
x_c=np.zeros(m+1)#Chebyshev Nodes
for i in range(0,len(x)):
    x_c[i]=cos((2.0*i+1.0)/(2.0*m+2.0)*pi)

# %%
zeros=np.zeros(m+1)
plt.plot(x_c,zeros,'bo')
plt.title(str(m)+' Chebyshev nodes')
# Out:
# Text(0.5, 1.0, '19 Chebyshev nodes')

# %%
#Extended Chebyshev nodes
x_ce=x_c/(cos(pi/(2.0*m+2)))
plt.plot(x_ce,zeros,'bo')
print(x_ce)
plt.title(str(m)+' Extended Chebyshev nodes')
# Out:
# [ 1.          0.97537668  0.92673635  0.8552767   0.76275729  0.65145627
#   0.52411423  0.38386677  0.23416722  0.07870171 -0.07870171 -0.23416722
#  -0.38386677 -0.52411423 -0.65145627 -0.76275729 -0.8552767  -0.92673635
#  -0.97537668 -1.        ]
# Text(0.5, 1.0, '19 Extended Chebyshev nodes')
